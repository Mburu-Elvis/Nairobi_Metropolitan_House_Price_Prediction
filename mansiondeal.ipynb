# %%
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport
import seaborn as sns
import matplotlib.pyplot as plt

# %%
house_data = pd.read_csv('./data/mansiondeal.csv')

# %%
profile = ProfileReport(house_data, title="Nairobi House Rent Prices", explorative=True)

profile.to_notebook_iframe()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 3
#       1 profile = ProfileReport(house_data, title="Nairobi House Rent Prices", explorative=True)
# ----> 3 profile.to_notebook_iframe()
#
# File ~/.local/lib/python3.10/site-packages/typeguard/__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~/.local/lib/python3.10/site-packages/pandas_profiling/profile_report.py:450, in ProfileReport.to_notebook_iframe(self)
#     448 with warnings.catch_warnings():
#     449     warnings.simplefilter("ignore")
# --> 450     display(get_notebook_iframe(self.config, self))
#
# ...
