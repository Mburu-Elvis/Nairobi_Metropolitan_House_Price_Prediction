# %%
import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'sans-serif'
matplotlib.rcParams['font.sans-serif'] = ['Arial']

# %%
import matplotlib.font_manager
print([f.name for f in matplotlib.font_manager.fontManager.ttflist])
# Out:
# ['cmmi10', 'STIXGeneral', 'STIXGeneral', 'STIXSizeOneSym', 'DejaVu Serif', 'STIXNonUnicode', 'DejaVu Sans', 'DejaVu Sans Mono', 'STIXNonUnicode', 'STIXSizeTwoSym', 'STIXNonUnicode', 'STIXSizeTwoSym', 'DejaVu Sans', 'STIXGeneral', 'cmtt10', 'cmss10', 'cmsy10', 'STIXSizeFourSym', 'DejaVu Serif', 'cmb10', 'cmr10', 'STIXGeneral', 'DejaVu Sans Mono', 'DejaVu Sans Display', 'STIXNonUnicode', 'STIXSizeThreeSym', 'STIXSizeFiveSym', 'DejaVu Sans', 'STIXSizeOneSym', 'DejaVu Sans', 'STIXSizeThreeSym', 'DejaVu Sans Mono', 'cmex10', 'DejaVu Serif', 'STIXSizeFourSym', 'DejaVu Serif', 'DejaVu Serif Display', 'DejaVu Sans Mono', 'Lohit Malayalam', 'Nimbus Mono PS', 'URW Gothic', 'Purisa', 'Liberation Serif', 'Norasi', 'Yrsa', 'Norasi', 'Nimbus Mono PS', 'RaghuMalayalamSans', 'FreeMono', 'FreeSans', 'Ubuntu', 'Khmer OS', 'Nimbus Sans', 'Pothana2000', 'Liberation Mono', 'Nimbus Mono PS', 'Gargi', 'Rekha', 'Ubuntu Condensed', 'Liberation Sans Narrow', 'Kinnari', 'DejaVu Serif', 'Ubuntu Mono', 'Norasi', 'Kalapi', 'Umpush', 'Garuda', 'Ubuntu', 'Navilu', 'Liberation Serif', 'Tlwg Mono', 'Waree', 'Padauk', 'Ubuntu Mono', 'NTR', 'DejaVu Sans Mono', 'FreeSans', 'Noto Serif CJK JP', 'URW Bookman', 'LKLUG', 'URW Gothic', 'Tlwg Typist', 'Noto Sans CJK JP', 'Chandas', 'Nimbus Sans', 'Lohit Tamil', 'P052', 'RaviPrakash', 'Lohit Tamil Classical', 'Liberation Sans', 'Liberation Sans', 'FreeSerif', 'Liberation Serif', 'DejaVu Sans', 'Nimbus Sans Narrow', 'Tlwg Typist', 'Garuda', 'KacstOffice', 'KacstQurn', 'Tlwg Typo', 'Padauk Book', 'C059', 'Garuda', 'Yrsa', 'URW Bookman', 'DejaVu Sans Mono', 'Tlwg Mono', 'FreeMono', 'C059', 'Purisa', 'Yrsa', 'Yrsa', 'Ubuntu', 'Umpush', 'Gayathri', 'Gurajada', 'Sahadeva', 'Manjari', 'Ubuntu', 'Padauk Book', 'Likhan', 'Lohit Gurmukhi', 'Rasa', 'Sawasdee', 'Manjari', 'Loma', 'Gayathri', 'Lohit Bengali', 'Lohit Telugu', 'Ramabhadra', 'Umpush', 'KacstBook', 'Dhurjati', 'Suranna', 'padmaa', 'FreeSerif', 'Phetsarath OT', 'Waree', 'Rasa', 'Sawasdee', 'Liberation Mono', 'FreeSerif', 'Ani', 'Abyssinica SIL', 'AnjaliOldLipi', 'Sree Krushnadevaraya', 'Liberation Mono', 'C059', 'Gayathri', 'Liberation Sans', 'Loma', 'Lohit Kannada', 'Loma', 'URW Bookman', 'Jamrul', 'Mukti', 'Khmer OS System', 'padmaa', 'C059', 'KacstTitle', 'Kinnari', 'URW Bookman', 'Purisa', 'Liberation Sans', 'Tlwg Typist', 'URW Gothic', 'Sarai', 'Lohit Assamese', 'Kinnari', 'Keraleeyam', 'Vemana2000', 'FreeSerif', 'KacstArt', 'Yrsa', 'Liberation Mono', 'Samyak Malayalam', 'Nimbus Roman', 'Noto Sans Mono', 'Mitra ', 'DejaVu Sans', 'Karumbi', 'Yrsa', 'URW Gothic', 'Liberation Sans', 'Tlwg Typewriter', 'Ubuntu', 'Laksaman', 'KacstOne', 'Syamala Ramana', 'KacstNaskh', 'Liberation Sans', 'KacstLetter', 'Droid Sans Fallback', 'Samyak Devanagari', 'Ramaraja', 'Potti Sreeramulu', 'Garuda', 'Kinnari', 'Nimbus Sans Narrow', 'D050000L', 'Liberation Serif', 'Kinnari', 'Rasa', 'Peddana', 'KacstFarsi', 'Chilanka', 'Tlwg Typo', 'Ubuntu Mono', 'Ubuntu', 'KacstOne', 'Tlwg Typewriter', 'Norasi', 'Tlwg Mono', 'LakkiReddy', 'Mukti', 'Samanata', 'Nimbus Sans Narrow', 'Laksaman', 'Nimbus Sans Narrow', 'Liberation Serif', 'KacstPen', 'padmaa-Bold.1.1', 'Yrsa', 'Nimbus Sans', 'Uroob', 'Nakula', 'NATS', 'Mandali', 'Dyuthi', 'Laksaman', 'KacstPoster', 'Liberation Mono', 'Nimbus Roman', 'Padauk', 'Lohit Gujarati', 'Tlwg Typo', 'mry_KacstQurn', 'FreeSans', 'Tibetan Machine Uni', 'KacstDecorative', 'Nimbus Mono PS', 'Liberation Serif', 'Samyak Gujarati', 'Rachana', 'Sawasdee', 'Sawasdee', 'ori1Uni', 'Umpush', 'Ponnala', 'Ubuntu', 'Rasa', 'Ubuntu', 'Standard Symbols PS', 'KacstDigital', 'Liberation Sans', 'Liberation Mono', 'Liberation Sans Narrow', 'Laksaman', 'Waree', 'Lohit Odia', 'Mallanna', 'Liberation Serif', 'Loma', 'Kalimati', 'DejaVu Serif', 'Tlwg Typewriter', 'Rachana', 'P052', 'Liberation Mono', 'Waree', 'Nimbus Roman', 'Tlwg Mono', 'KacstScreen', 'P052', 'Kinnari', 'Manjari', 'Noto Sans CJK JP', 'OpenSymbol', 'Liberation Sans Narrow', 'Umpush', 'Yrsa', 'Yrsa', 'Rasa', 'Liberation Seri ...

# %%
house_data = pd.read_csv('./data/mansiondeal.csv')

# %%
profile = ProfileReport(house_data, title="Nairobi House Rent Prices")

# %%
profile.to_notebook_iframe()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 profile.to_notebook_iframe()
#
# File ~/.local/lib/python3.10/site-packages/typeguard/__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/profile_report.py:515, in ProfileReport.to_notebook_iframe(self)
#     513 with warnings.catch_warnings():
#     514     warnings.simplefilter("ignore")
# --> 515     display(get_notebook_iframe(self.config, self))
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/report/presentation/flavours/widget/notebook.py:75, in get_notebook_iframe(config, profile)
#      73     output = get_notebook_iframe_src(config, profile)
#      74 elif attribute == IframeAttribute.srcdoc:
# ---> 75     output = get_notebook_iframe_srcdoc(config, profile)
#      76 else:
#      77     raise ValueError(
#      78         f'Iframe Attribute can be "src" or "srcdoc" (current: {attribute}).'
#      79     )
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/report/presentation/flavours/widget/notebook.py:29, in get_notebook_iframe_srcdoc(config, profile)
#      27 width = config.notebook.iframe.width
#      28 height = config.notebook.iframe.height
# ---> 29 src = html.escape(profile.to_html())
#      31 iframe = f'<iframe width="{width}" height="{height}" srcdoc="{src}" frameborder="0" allowfullscreen></iframe>'
#      33 return HTML(iframe)
#
# File ~/.local/lib/python3.10/site-packages/typeguard/__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/profile_report.py:485, in ProfileReport.to_html(self)
#     477 def to_html(self) -> str:
#     478     """Generate and return complete template as lengthy string
#     479         for using with frameworks.
#     480
#    (...)
#     483
#     484     """
# --> 485     return self.html
#
# File ~/.local/lib/python3.10/site-packages/typeguard/__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/profile_report.py:283, in ProfileReport.html(self)
#     280 @property
#     281 def html(self) -> str:
#     282     if self._html is None:
# --> 283         self._html = self._render_html()
#     284     return self._html
#
# File ~/.local/lib/python3.10/site-packages/typeguard/__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/profile_report.py:400, in ProfileReport._render_html(self)
#     397 def _render_html(self) -> str:
#     398     from ydata_profiling.report.presentation.flavours import HTMLReport
# --> 400     report = self.report
#     402     with tqdm(
#     403         total=1, desc="Render HTML", disable=not self.config.progress_bar
#     404     ) as pbar:
#     405         html = HTMLReport(copy.deepcopy(report)).render(
#     406             nav=self.config.html.navbar_show,
#     407             offline=self.config.html.use_local_assets,
#    (...)
#     415             version=self.description_set.package["ydata_profiling_version"],
#     416         )
#
# File ~/.local/lib/python3.10/site-packages/typeguard/__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/profile_report.py:277, in ProfileReport.report(self)
#     274 @property
#     275 def report(self) -> Root:
#     276     if self._report is None:
# --> 277         self._report = get_report_structure(self.config, self.description_set)
#     278     return self._report
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/report/structure/report.py:387, in get_report_structure(config, summary)
#     368 section_items: List[Renderable] = [
#     369     Container(
#     370         get_dataset_items(config, summary, alerts),
#    (...)
#     374     ),
#     375 ]
#     377 if len(summary.variables) > 0:
#     378     section_items.append(
#     379         Dropdown(
#     380             name="Variables",
#     381             anchor_id="variables-dropdown",
#     382             id="variables-dropdown",
#     383             is_row=True,
#     384             classes=["dropdown-toggle"],
#     385             items=list(summary.variables),
#     386             item=Container(
# --> 387                 render_variables_section(config, summary),
#     388                 sequence_type="accordion",
#     389                 name="Variables",
#     390                 anchor_id="variables",
#     391             ),
#     392         )
#     393     )
#     395 scatter_items = get_interactions(config, summary.scatter)
#     396 if len(scatter_items) > 0:
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/report/structure/report.py:162, in render_variables_section(config, dataframe_summary)
#     160     variable_type = summary["type"]
#     161 render_map_type = render_map.get(variable_type, render_map["Unsupported"])
# --> 162 template_variables.update(render_map_type(config, template_variables))
#     164 # Ignore these
#     165 if reject_variables:
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/report/structure/variables/render_text.py:81, in render_text(config, summary)
#      77 top_items.append(table)
#      79 if words and "word_counts" in summary:
#      80     mini_wordcloud = Image(
# ---> 81         plot_word_cloud(config, summary["word_counts"]),
#      82         image_format=config.plot.image_format,
#      83         alt="Mini wordcloud",
#      84     )
#      85     top_items.append(mini_wordcloud)
#      86 template_variables["top"] = Container(top_items, sequence_type="grid")
#
# File /usr/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/visualisation/plot.py:127, in plot_word_cloud(config, word_counts)
#     125 @manage_matplotlib_context()
#     126 def plot_word_cloud(config: Settings, word_counts: pd.Series) -> str:
# --> 127     _plot_word_cloud(series=word_counts)
#     128     return plot_360_n0sc0pe(config)
#
# File ~/.local/lib/python3.10/site-packages/ydata_profiling/visualisation/plot.py:40, in _plot_word_cloud(series, figsize)
#      36 for i, series_data in enumerate(series):
#      37     word_dict = series_data.to_dict()
#      38     wordcloud = WordCloud(
#      39         background_color="white", random_state=123, width=300, height=200, scale=2
# ---> 40     ).generate_from_frequencies(word_dict)
#      42     ax = plot.add_subplot(1, len(series), i + 1)
#      43     ax.imshow(wordcloud)
#
# File ~/.local/lib/python3.10/site-packages/wordcloud/wordcloud.py:453, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     451     font_size = self.height
#     452 else:
# --> 453     self.generate_from_frequencies(dict(frequencies[:2]),
#     454                                    max_font_size=self.height)
#     455     # find font sizes
#     456     sizes = [x[1] for x in self.layout_]
#
# File ~/.local/lib/python3.10/site-packages/wordcloud/wordcloud.py:511, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     508 transposed_font = ImageFont.TransposedFont(
#     509     font, orientation=orientation)
#     510 # get size of resulting text
# --> 511 box_size = draw.textbbox((0, 0), word, font=transposed_font, anchor="lt")
#     512 # find possible places using integral image:
#     513 result = occupancy.sample_position(box_size[3] + self.margin,
#     514                                    box_size[2] + self.margin,
#     515                                    random_state)
#
# File /usr/lib/python3/dist-packages/PIL/ImageDraw.py:671, in ImageDraw.textbbox(self, xy, text, font, anchor, spacing, align, direction, features, language, stroke_width, embedded_color)
#     669     font = self.getfont()
#     670 if not isinstance(font, ImageFont.FreeTypeFont):
# --> 671     raise ValueError("Only supported for TrueType fonts")
#     672 mode = "RGBA" if embedded_color else self.fontmode
#     673 bbox = font.getbbox(
#     674     text, mode, direction, features, language, stroke_width, anchor
#     675 )
#
# ValueError: Only supported for TrueType fonts
